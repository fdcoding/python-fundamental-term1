# %% [markdown]
# ## home work question 1- list all square numbers
#
# if we multiple a number by itself we get a square number, the first 3 square number is 1 (1*1), 4 (2*2) and 9 (3*3)
# please write a program list all the square number which less than 500

# %% [markdown]
# ## home work question 2-- how many numbers can I build
# Tom has 4 poker cards, and each card has one of the numbers 1, 4, 5, and 7 on it. this time he want to pick up 3 cards and build 3 digital numbers, for example, he can pickup 1, 5, 7 and build a 3 digital number "517", please write a program list all the 3 digital numbers

# %% [markdown]
# ![Python%20Fundamental%20Term%201%20%20Lesson%20six%20Python%20lists.jpg](attachment:Python%20Fundamental%20Term%201%20%20Lesson%20six%20Python%20lists.jpg)
